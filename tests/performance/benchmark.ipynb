# %% [markdown]
# This is the performance measurement of the geoserver LIWO production

# %%
server_url = 'https://geodata.basisinformatie-overstromingen.nl'
path = '/geoserver/wms?service=WMS&request=GetMap&layers=MEGO%3AMEGO_overstromingNL_WaterdiepteKlasse_Group&styles=&format=image%2Fpng&transparent=true&version=1.1.1&baselayer=false&tiled=true&height=256&width=256&srs=EPSG%3A28992&bbox=155000.00011739583,463000.00044581917,168762.56012993932,476762.560'
url = f'{server_url}{path}'
# !ab -n 20 -c 5 "$url"
# Out:
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking geodata.basisinformatie-overstromingen.nl (be patient).....done
#
#
# Server Software:        Apache-Coyote/1.1
# Server Hostname:        geodata.basisinformatie-overstromingen.nl
# Server Port:            443
# SSL/TLS Protocol:       TLSv1.2,ECDHE-RSA-AES128-GCM-SHA256,2048,128
# Server Temp Key:        ECDH P-256 256 bits
# TLS Server Name:        geodata.basisinformatie-overstromingen.nl
#
# Document Path:          /geoserver/wms?service=WMS&request=GetMap&layers=MEGO%3AMEGO_overstromingNL_WaterdiepteKlasse_Group&styles=&format=image%2Fpng&transparent=true&version=1.1.1&baselayer=false&tiled=true&height=256&width=256&srs=EPSG%3A28992&bbox=155000.00011739583,463000.00044581917,168762.56012993932,476762.560
# Document Length:        14104 bytes
#
# Concurrency Level:      5
# Time taken for tests:   7.779 seconds
# Complete requests:      20
# Failed requests:        0
# Total transferred:      287740 bytes
# HTML transferred:       282080 bytes
# Requests per second:    2.57 [#/sec] (mean)
# Time per request:       1944.854 [ms] (mean)
# Time per request:       388.971 [ms] (mean, across all concurrent requests)
# Transfer rate:          36.12 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:      109  137  44.4    121     313
# Processing:  1207 1407 178.1   1391    2069
# Waiting:     1200 1402 177.3   1385    2059
# Total:       1347 1544 175.5   1527    2203
#
# Percentage of the requests served within a certain time (ms)
#   50%   1527
#   66%   1582
#   75%   1598
#   80%   1604
#   90%   1639
#   95%   2203
#   98%   2203
#   99%   2203
#  100%   2203 (longest request)

# %% [markdown]
# This is the performance measurement of the backend LIWO production

# %%
server_url = 'https://geodata.basisinformatie-overstromingen.nl'
path = '/overstroom-ik.html?adres=2631TG&latitude=&longiqtude='
url = f'{server_url}{path}'
# !ab -n 20 -c 5 "$url"
# Out:
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking geodata.basisinformatie-overstromingen.nl (be patient).....done
#
#
# Server Software:        Apache-Coyote/1.1
# Server Hostname:        geodata.basisinformatie-overstromingen.nl
# Server Port:            443
# SSL/TLS Protocol:       TLSv1.2,ECDHE-RSA-AES128-GCM-SHA256,2048,128
# Server Temp Key:        ECDH P-256 256 bits
# TLS Server Name:        geodata.basisinformatie-overstromingen.nl
#
# Document Path:          /overstroom-ik.html?adres=2631TG&latitude=&longiqtude=
# Document Length:        127 bytes
#
# Concurrency Level:      5
# Time taken for tests:   0.816 seconds
# Complete requests:      20
# Failed requests:        0
# Non-2xx responses:      20
# Total transferred:      7740 bytes
# HTML transferred:       2540 bytes
# Requests per second:    24.52 [#/sec] (mean)
# Time per request:       203.951 [ms] (mean)
# Time per request:       40.790 [ms] (mean, across all concurrent requests)
# Transfer rate:          9.27 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:      110  127   9.6    126     149
# Processing:    34   37   2.0     37      41
# Waiting:       33   35   1.8     35      38
# Total:        145  163  10.9    162     187
#
# Percentage of the requests served within a certain time (ms)
#   50%    162
#   66%    169
#   75%    171
#   80%    175
#   90%    180
#   95%    187
#   98%    187
#   99%    187
#  100%    187 (longest request)

# %% [markdown]
# This is the performance measurement of the backend overstroomik test environment

# %%
server_url = 'http://34.120.151.162'
path = '/'
url = f'{server_url}{path}'
# !ab -n 20 -c 5 "$url"
# Out:
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /
# Document Length:        71 bytes
#
# Concurrency Level:      5
# Time taken for tests:   0.460 seconds
# Complete requests:      20
# Failed requests:        0
# Non-2xx responses:      20
# Total transferred:      4240 bytes
# HTML transferred:       1420 bytes
# Requests per second:    43.45 [#/sec] (mean)
# Time per request:       115.079 [ms] (mean)
# Time per request:       23.016 [ms] (mean, across all concurrent requests)
# Transfer rate:          9.00 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   10   1.5     10      12
# Processing:    15   91  58.3     90     192
# Waiting:       14   90  58.5     89     192
# Total:         22  101  58.5    100     201
#
# Percentage of the requests served within a certain time (ms)
#   50%    100
#   66%    101
#   75%    101
#   80%    199
#   90%    200
#   95%    201
#   98%    201
#   99%    201
#  100%    201 (longest request)

# %% [markdown]
# This is the performance measurement of the backend overstroomik test environment (function by_rd)

# %%
server_url = 'http://34.120.151.162'
path = '/by_rd?x={x}&y={y}'
url = f'{server_url}{path}'

x = 160544.902
y = 502115.495
import random
for i in range(100):
    url = url.format(x=x + random.random(),y =y + random.random())
    # !ab -n 10 -c 10 "$url"
# Out:
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.170 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    58.92 [#/sec] (mean)
# Time per request:       169.708 [ms] (mean)
# Time per request:       16.971 [ms] (mean, across all concurrent requests)
# Transfer rate:          12.49 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   10   2.4     11      13
# Processing:    17   75  60.1    131     135
# Waiting:       16   74  59.9    129     135
# Total:         24   85  61.8    143     144
#
# Percentage of the requests served within a certain time (ms)
#   50%    143
#   66%    144
#   75%    144
#   80%    144
#   90%    144
#   95%    144
#   98%    144
#   99%    144
#  100%    144 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.274 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    36.53 [#/sec] (mean)
# Time per request:       273.722 [ms] (mean)
# Time per request:       27.372 [ms] (mean, across all concurrent requests)
# Transfer rate:          7.74 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   10   2.6     11      14
# Processing:    16   61  65.0     44     244
# Waiting:       15   60  65.4     44     244
# Total:         23   71  64.4     54     252
#
# Percentage of the requests served within a certain time (ms)
#   50%     54
#   66%     55
#   75%     55
#   80%     55
#   90%    252
#   95%    252
#   98%    252
#   99%    252
#  100%    252 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.172 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    58.16 [#/sec] (mean)
# Time per request:       171.933 [ms] (mean)
# Time per request:       17.193 [ms] (mean, across all concurrent requests)
# Transfer rate:          12.33 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        6   10   2.9     10      14
# Processing:    15   58  54.7     40     136
# Waiting:       15   57  54.6     40     135
# Total:         22   68  57.3     50     150
#
# Percentage of the requests served within a certain time (ms)
#   50%     50
#   66%     50
#   75%    149
#   80%    150
#   90%    150
#   95%    150
#   98%    150
#   99%    150
#  100%    150 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.159 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    62.77 [#/sec] (mean)
# Time per request:       159.305 [ms] (mean)
# Time per request:       15.931 [ms] (mean, across all concurrent requests)
# Transfer rate:          13.30 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   11   2.5     12      14
# Processing:    16   45  41.9     27     125
# Waiting:       15   44  42.3     25     124
# Total:         23   56  42.6     38     137
#
# Percentage of the requests served within a certain time (ms)
#   50%     38
#   66%     38
#   75%     38
#   80%    136
#   90%    137
#   95%    137
#   98%    137
#   99%    137
#  100%    137 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.174 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    57.52 [#/sec] (mean)
# Time per request:       173.844 [ms] (mean)
# Time per request:       17.384 [ms] (mean, across all concurrent requests)
# Transfer rate:          12.19 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   10   2.5      9      14
# Processing:    17   81  23.8     90      94
# Waiting:       17   80  23.5     89      92
# Total:         24   91  24.9    101     102
#
# Percentage of the requests served within a certain time (ms)
#   50%    101
#   66%    102
#   75%    102
#   80%    102
#   90%    102
#   95%    102
#   98%    102
#   99%    102
#  100%    102 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.175 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    57.14 [#/sec] (mean)
# Time per request:       175.016 [ms] (mean)
# Time per request:       17.502 [ms] (mean, across all concurrent requests)
# Transfer rate:          12.11 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7    9   1.0      9      10
# Processing:    15   60  56.9     42     142
# Waiting:       15   60  56.5     42     141
# Total:         22   70  57.7     52     153
#
# Percentage of the requests served within a certain time (ms)
#   50%     52
#   66%     52
#   75%    152
#   80%    152
#   90%    153
#   95%    153
#   98%    153
#   99%    153
#  100%    153 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.276 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    36.23 [#/sec] (mean)
# Time per request:       276.027 [ms] (mean)
# Time per request:       27.603 [ms] (mean, across all concurrent requests)
# Transfer rate:          7.68 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   10   2.1     10      13
# Processing:    16  160 105.9    241     244
# Waiting:       14  159 106.0    239     244
# Total:         23  171 107.7    254     254
#
# Percentage of the requests served within a certain time (ms)
#   50%    254
#   66%    254
#   75%    254
#   80%    254
#   90%    254
#   95%    254
#   98%    254
#   99%    254
#  100%    254 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.075 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    133.77 [#/sec] (mean)
# Time per request:       74.757 [ms] (mean)
# Time per request:       7.476 [ms] (mean, across all concurrent requests)
# Transfer rate:          28.35 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   10   2.5     11      15
# Processing:    18   35   9.2     39      44
# Waiting:       15   34  10.0     38      42
# Total:         24   46  10.8     50      53
#
# Percentage of the requests served within a certain time (ms)
#   50%     50
#   66%     51
#   75%     51
#   80%     53
#   90%     53
#   95%     53
#   98%     53
#   99%     53
#  100%     53 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.362 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    27.65 [#/sec] (mean)
# Time per request:       361.700 [ms] (mean)
# Time per request:       36.170 [ms] (mean, across all concurrent requests)
# Transfer rate:          5.86 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   10   2.8      9      13
# Processing:    54  217 100.9    287     294
# Waiting:       54  217 101.1    287     294
# Total:         61  227 101.6    301     301
#
# Percentage of the requests served within a certain time (ms)
#   50%    301
#   66%    301
#   75%    301
#   80%    301
#   90%    301
#   95%    301
#   98%    301
#   99%    301
#  100%    301 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.071 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    141.76 [#/sec] (mean)
# Time per request:       70.542 [ms] (mean)
# Time per request:       7.054 [ms] (mean, across all concurrent requests)
# Transfer rate:          30.04 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   10   2.2     11      13
# Processing:    15   36   7.4     38      40
# Waiting:       15   35   7.4     38      40
# Total:         22   46   8.4     49      49
#
# Percentage of the requests served within a certain time (ms)
#   50%     49
#   66%     49
#   75%     49
#   80%     49
#   90%     49
#   95%     49
#   98%     49
#   99%     49
#  100%     49 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.357 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    28.04 [#/sec] (mean)
# Time per request:       356.674 [ms] (mean)
# Time per request:       35.667 [ms] (mean, across all concurrent requests)
# Transfer rate:          5.94 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   11   3.5     12      16
# Processing:    16  208 103.4    286     293
# Waiting:       16  207 103.5    285     293
# Total:         24  219 105.4    301     302
#
# Percentage of the requests served within a certain time (ms)
#   50%    301
#   66%    301
#   75%    301
#   80%    301
#   90%    302
#   95%    302
#   98%    302
#   99%    302
#  100%    302 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.261 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    38.27 [#/sec] (mean)
# Time per request:       261.277 [ms] (mean)
# Time per request:       26.128 [ms] (mean, across all concurrent requests)
# Transfer rate:          8.11 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   10   2.7     10      14
# Processing:    15   96  73.0    130     230
# Waiting:       14   95  73.0    127     230
# Total:         22  106  73.8    142     240
#
# Percentage of the requests served within a certain time (ms)
#   50%    142
#   66%    142
#   75%    142
#   80%    143
#   90%    240
#   95%    240
#   98%    240
#   99%    240
#  100%    240 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.175 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    56.99 [#/sec] (mean)
# Time per request:       175.476 [ms] (mean)
# Time per request:       17.548 [ms] (mean, across all concurrent requests)
# Transfer rate:          12.08 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7    9   1.7      8      12
# Processing:    14  103  60.2    140     142
# Waiting:       14  102  60.1    138     142
# Total:         21  112  61.2    150     152
#
# Percentage of the requests served within a certain time (ms)
#   50%    150
#   66%    150
#   75%    150
#   80%    150
#   90%    152
#   95%    152
#   98%    152
#   99%    152
#  100%    152 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.165 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    60.73 [#/sec] (mean)
# Time per request:       164.655 [ms] (mean)
# Time per request:       16.465 [ms] (mean, across all concurrent requests)
# Transfer rate:          12.87 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   10   2.4     10      13
# Processing:    15   68  55.2     33     136
# Waiting:       14   68  55.5     33     134
# Total:         22   78  55.5     42     143
#
# Percentage of the requests served within a certain time (ms)
#   50%     42
#   66%    141
#   75%    142
#   80%    142
#   90%    143
#   95%    143
#   98%    143
#   99%    143
#  100%    143 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.172 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    58.15 [#/sec] (mean)
# Time per request:       171.968 [ms] (mean)
# Time per request:       17.197 [ms] (mean, across all concurrent requests)
# Transfer rate:          12.32 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        8    9   0.9      9      10
# Processing:    16   60  51.4     36     134
# Waiting:       15   58  51.8     34     133
# Total:         24   69  52.2     45     144
#
# Percentage of the requests served within a certain time (ms)
#   50%     45
#   66%     45
#   75%    144
#   80%    144
#   90%    144
#   95%    144
#   98%    144
#   99%    144
#  100%    144 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.172 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    58.27 [#/sec] (mean)
# Time per request:       171.607 [ms] (mean)
# Time per request:       17.161 [ms] (mean, across all concurrent requests)
# Transfer rate:          12.35 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   11   3.4     14      14
# Processing:    15   41  35.0     37     136
# Waiting:       15   41  35.1     37     136
# Total:         22   52  36.8     51     150
#
# Percentage of the requests served within a certain time (ms)
#   50%     51
#   66%     51
#   75%     51
#   80%     52
#   90%    150
#   95%    150
#   98%    150
#   99%    150
#  100%    150 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.159 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    62.77 [#/sec] (mean)
# Time per request:       159.303 [ms] (mean)
# Time per request:       15.930 [ms] (mean, across all concurrent requests)
# Transfer rate:          13.30 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7    9   1.3     10      12
# Processing:    16   33  33.2     28     127
# Waiting:       15   33  33.1     27     126
# Total:         24   43  33.5     37     136
#
# Percentage of the requests served within a certain time (ms)
#   50%     37
#   66%     37
#   75%     38
#   80%     38
#   90%    136
#   95%    136
#   98%    136
#   99%    136
#  100%    136 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.173 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    57.82 [#/sec] (mean)
# Time per request:       172.955 [ms] (mean)
# Time per request:       17.295 [ms] (mean, across all concurrent requests)
# Transfer rate:          12.25 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   10   2.4     12      13
# Processing:    15   39  36.5     34     139
# Waiting:       15   38  36.5     34     138
# Total:         22   49  37.3     48     151
#
# Percentage of the requests served within a certain time (ms)
#   50%     48
#   66%     48
#   75%     48
#   80%     49
#   90%    151
#   95%    151
#   98%    151
#   99%    151
#  100%    151 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.156 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    63.95 [#/sec] (mean)
# Time per request:       156.370 [ms] (mean)
# Time per request:       15.637 [ms] (mean, across all concurrent requests)
# Transfer rate:          13.55 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        6   10   2.9     11      14
# Processing:    16   32  32.0     23     123
# Waiting:       16   32  32.2     23     123
# Total:         23   42  32.4     35     133
#
# Percentage of the requests served within a certain time (ms)
#   50%     35
#   66%     35
#   75%     35
#   80%     35
#   90%    133
#   95%    133
#   98%    133
#   99%    133
#  100%    133 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.274 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    36.47 [#/sec] (mean)
# Time per request:       274.204 [ms] (mean)
# Time per request:       27.420 [ms] (mean, across all concurrent requests)
# Transfer rate:          7.73 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   10   1.7     10      13
# Processing:    16  127  66.2    141     241
# Waiting:       15  126  66.3    141     241
# Total:         23  137  67.2    153     251
#
# Percentage of the requests served within a certain time (ms)
#   50%    153
#   66%    153
#   75%    154
#   80%    158
#   90%    251
#   95%    251
#   98%    251
#   99%    251
#  100%    251 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.271 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    36.84 [#/sec] (mean)
# Time per request:       271.421 [ms] (mean)
# Time per request:       27.142 [ms] (mean, across all concurrent requests)
# Transfer rate:          7.81 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        8   11   2.3     10      15
# Processing:    16   56  64.5     40     239
# Waiting:       14   55  64.7     38     238
# Total:         24   68  64.3     50     249
#
# Percentage of the requests served within a certain time (ms)
#   50%     50
#   66%     50
#   75%     51
#   80%     52
#   90%    249
#   95%    249
#   98%    249
#   99%    249
#  100%    249 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.266 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    37.63 [#/sec] (mean)
# Time per request:       265.729 [ms] (mean)
# Time per request:       26.573 [ms] (mean, across all concurrent requests)
# Transfer rate:          7.97 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        6    8   1.2      8      10
# Processing:    14   76  91.2     33     236
# Waiting:       13   76  91.2     33     236
# Total:         21   84  91.9     41     245
#
# Percentage of the requests served within a certain time (ms)
#   50%     41
#   66%     42
#   75%    143
#   80%    245
#   90%    245
#   95%    245
#   98%    245
#   99%    245
#  100%    245 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.771 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    12.96 [#/sec] (mean)
# Time per request:       771.338 [ms] (mean)
# Time per request:       77.134 [ms] (mean, across all concurrent requests)
# Transfer rate:          2.75 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7    9   1.6     10      11
# Processing:    15  288 277.8    242     739
# Waiting:       15  287 278.0    241     739
# Total:         22  297 278.2    251     749
#
# Percentage of the requests served within a certain time (ms)
#   50%    251
#   66%    451
#   75%    549
#   80%    649
#   90%    749
#   95%    749
#   98%    749
#   99%    749
#  100%    749 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.668 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    14.96 [#/sec] (mean)
# Time per request:       668.252 [ms] (mean)
# Time per request:       66.825 [ms] (mean, across all concurrent requests)
# Transfer rate:          3.17 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        6    8   1.0      8       9
# Processing:    13  202 152.7    193     594
# Waiting:       13  201 152.4    192     593
# Total:         22  210 152.1    201     600
#
# Percentage of the requests served within a certain time (ms)
#   50%    201
#   66%    201
#   75%    201
#   80%    207
#   90%    600
#   95%    600
#   98%    600
#   99%    600
#  100%    600 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.245 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    40.88 [#/sec] (mean)
# Time per request:       244.601 [ms] (mean)
# Time per request:       24.460 [ms] (mean, across all concurrent requests)
# Transfer rate:          8.66 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:       10   13   1.5     13      15
# Processing:    19   81  58.7    103     203
# Waiting:       17   80  58.8    102     202
# Total:         29   95  59.4    118     216
#
# Percentage of the requests served within a certain time (ms)
#   50%    118
#   66%    118
#   75%    118
#   80%    119
#   90%    216
#   95%    216
#   98%    216
#   99%    216
#  100%    216 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.159 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    63.05 [#/sec] (mean)
# Time per request:       158.603 [ms] (mean)
# Time per request:       15.860 [ms] (mean, across all concurrent requests)
# Transfer rate:          13.36 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        6    9   2.2     10      12
# Processing:    15   36  32.0     27     125
# Waiting:       14   34  32.0     26     124
# Total:         22   45  33.0     38     137
#
# Percentage of the requests served within a certain time (ms)
#   50%     38
#   66%     38
#   75%     38
#   80%     44
#   90%    137
#   95%    137
#   98%    137
#   99%    137
#  100%    137 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.162 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    61.79 [#/sec] (mean)
# Time per request:       161.847 [ms] (mean)
# Time per request:       16.185 [ms] (mean, across all concurrent requests)
# Transfer rate:          13.09 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   11   1.5     11      12
# Processing:    18   40  31.9     32     129
# Waiting:       14   38  32.1     30     128
# Total:         25   50  32.3     42     141
#
# Percentage of the requests served within a certain time (ms)
#   50%     42
#   66%     43
#   75%     43
#   80%     43
#   90%    141
#   95%    141
#   98%    141
#   99%    141
#  100%    141 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.164 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    60.93 [#/sec] (mean)
# Time per request:       164.130 [ms] (mean)
# Time per request:       16.413 [ms] (mean, across all concurrent requests)
# Transfer rate:          12.91 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        8    9   0.6      9      10
# Processing:    53   89  12.7     93      95
# Waiting:       52   87  12.2     90      93
# Total:         61   98  13.0    102     104
#
# Percentage of the requests served within a certain time (ms)
#   50%    102
#   66%    103
#   75%    103
#   80%    103
#   90%    104
#   95%    104
#   98%    104
#   99%    104
#  100%    104 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.356 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    28.13 [#/sec] (mean)
# Time per request:       355.503 [ms] (mean)
# Time per request:       35.550 [ms] (mean, across all concurrent requests)
# Transfer rate:          5.96 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        8   10   2.0      9      13
# Processing:    50  108  65.9     93     291
# Waiting:       47  106  66.3     91     290
# Total:         58  117  65.8    102     300
#
# Percentage of the requests served within a certain time (ms)
#   50%    102
#   66%    103
#   75%    103
#   80%    103
#   90%    300
#   95%    300
#   98%    300
#   99%    300
#  100%    300 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.165 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    60.45 [#/sec] (mean)
# Time per request:       165.435 [ms] (mean)
# Time per request:       16.544 [ms] (mean, across all concurrent requests)
# Transfer rate:          12.81 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7    9   1.7      8      13
# Processing:    15   43  31.3     36     130
# Waiting:       14   42  31.3     35     129
# Total:         24   52  32.5     45     143
#
# Percentage of the requests served within a certain time (ms)
#   50%     45
#   66%     45
#   75%     45
#   80%     45
#   90%    143
#   95%    143
#   98%    143
#   99%    143
#  100%    143 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.271 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    36.85 [#/sec] (mean)
# Time per request:       271.398 [ms] (mean)
# Time per request:       27.140 [ms] (mean, across all concurrent requests)
# Transfer rate:          7.81 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   11   2.5     12      13
# Processing:    15  116  67.7    139     238
# Waiting:       14  115  67.8    137     238
# Total:         22  127  67.8    151     249
#
# Percentage of the requests served within a certain time (ms)
#   50%    151
#   66%    151
#   75%    151
#   80%    151
#   90%    249
#   95%    249
#   98%    249
#   99%    249
#  100%    249 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.072 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    139.31 [#/sec] (mean)
# Time per request:       71.782 [ms] (mean)
# Time per request:       7.178 [ms] (mean, across all concurrent requests)
# Transfer rate:          29.52 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   10   2.4     10      14
# Processing:    14   39   9.0     41      45
# Waiting:       12   36   8.7     39      43
# Total:         21   48   9.7     52      52
#
# Percentage of the requests served within a certain time (ms)
#   50%     52
#   66%     52
#   75%     52
#   80%     52
#   90%     52
#   95%     52
#   98%     52
#   99%     52
#  100%     52 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.261 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    38.36 [#/sec] (mean)
# Time per request:       260.691 [ms] (mean)
# Time per request:       26.069 [ms] (mean, across all concurrent requests)
# Transfer rate:          8.13 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   11   3.6     10      16
# Processing:    21  111  71.7     90     193
# Waiting:       20  111  72.3     89     193
# Total:         29  122  72.6    100     202
#
# Percentage of the requests served within a certain time (ms)
#   50%    100
#   66%    201
#   75%    201
#   80%    201
#   90%    202
#   95%    202
#   98%    202
#   99%    202
#  100%    202 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.364 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    27.44 [#/sec] (mean)
# Time per request:       364.463 [ms] (mean)
# Time per request:       36.446 [ms] (mean, across all concurrent requests)
# Transfer rate:          5.81 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   11   2.6     12      14
# Processing:    16  159  80.9    190     289
# Waiting:       16  159  80.9    190     288
# Total:         23  170  82.4    202     301
#
# Percentage of the requests served within a certain time (ms)
#   50%    202
#   66%    202
#   75%    202
#   80%    203
#   90%    301
#   95%    301
#   98%    301
#   99%    301
#  100%    301 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.166 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    60.42 [#/sec] (mean)
# Time per request:       165.519 [ms] (mean)
# Time per request:       16.552 [ms] (mean, across all concurrent requests)
# Transfer rate:          12.80 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   10   2.2     11      13
# Processing:    15   99  54.1    132     136
# Waiting:       14   97  53.5    130     133
# Total:         22  109  55.2    143     144
#
# Percentage of the requests served within a certain time (ms)
#   50%    143
#   66%    143
#   75%    143
#   80%    143
#   90%    144
#   95%    144
#   98%    144
#   99%    144
#  100%    144 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.268 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    37.30 [#/sec] (mean)
# Time per request:       268.080 [ms] (mean)
# Time per request:       26.808 [ms] (mean, across all concurrent requests)
# Transfer rate:          7.90 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   10   2.6     10      14
# Processing:    62   98  34.4     93     192
# Waiting:       61   97  34.4     92     191
# Total:         69  108  34.0    102     200
#
# Percentage of the requests served within a certain time (ms)
#   50%    102
#   66%    102
#   75%    103
#   80%    104
#   90%    200
#   95%    200
#   98%    200
#   99%    200
#  100%    200 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.263 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# ...
#
# Percentage of the requests served within a certain time (ms)
#   50%    151
#   66%    151
#   75%    152
#   80%    152
#   90%    153
#   95%    153
#   98%    153
#   99%    153
#  100%    153 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.277 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    36.12 [#/sec] (mean)
# Time per request:       276.862 [ms] (mean)
# Time per request:       27.686 [ms] (mean, across all concurrent requests)
# Transfer rate:          7.65 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   13   3.4     14      17
# Processing:    68  177  38.5    188     194
# Waiting:       66  175  38.4    188     191
# Total:         75  189  40.2    202     203
#
# Percentage of the requests served within a certain time (ms)
#   50%    202
#   66%    202
#   75%    202
#   80%    203
#   90%    203
#   95%    203
#   98%    203
#   99%    203
#  100%    203 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.277 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    36.17 [#/sec] (mean)
# Time per request:       276.501 [ms] (mean)
# Time per request:       27.650 [ms] (mean, across all concurrent requests)
# Transfer rate:          7.66 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   10   1.3      9      12
# Processing:    19   86  47.4     91     190
# Waiting:       18   85  47.8     91     189
# Total:         29   96  47.8    102     201
#
# Percentage of the requests served within a certain time (ms)
#   50%    102
#   66%    103
#   75%    103
#   80%    110
#   90%    201
#   95%    201
#   98%    201
#   99%    201
#  100%    201 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.273 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    36.67 [#/sec] (mean)
# Time per request:       272.666 [ms] (mean)
# Time per request:       27.267 [ms] (mean, across all concurrent requests)
# Transfer rate:          7.77 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   11   1.7     11      13
# Processing:    16  107  70.5    139     239
# Waiting:       16  106  70.4    139     238
# Total:         23  118  71.0    151     250
#
# Percentage of the requests served within a certain time (ms)
#   50%    151
#   66%    151
#   75%    151
#   80%    151
#   90%    250
#   95%    250
#   98%    250
#   99%    250
#  100%    250 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.277 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    36.06 [#/sec] (mean)
# Time per request:       277.342 [ms] (mean)
# Time per request:       27.734 [ms] (mean, across all concurrent requests)
# Transfer rate:          7.64 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   11   2.2     12      13
# Processing:    13   93  84.4    146     250
# Waiting:       12   92  84.3    144     249
# Total:         20  103  85.0    158     259
#
# Percentage of the requests served within a certain time (ms)
#   50%    158
#   66%    159
#   75%    159
#   80%    159
#   90%    259
#   95%    259
#   98%    259
#   99%    259
#  100%    259 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.281 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    35.58 [#/sec] (mean)
# Time per request:       281.094 [ms] (mean)
# Time per request:       28.109 [ms] (mean, across all concurrent requests)
# Transfer rate:          7.54 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   15   3.0     16      18
# Processing:    84   97  25.8     90     170
# Waiting:       82   93  26.7     86     169
# Total:        101  112  23.1    105     177
#
# Percentage of the requests served within a certain time (ms)
#   50%    105
#   66%    105
#   75%    105
#   80%    105
#   90%    177
#   95%    177
#   98%    177
#   99%    177
#  100%    177 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.370 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    27.01 [#/sec] (mean)
# Time per request:       370.209 [ms] (mean)
# Time per request:       37.021 [ms] (mean, across all concurrent requests)
# Transfer rate:          5.72 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        8   14   2.3     15      16
# Processing:    28  152  65.9    186     187
# Waiting:       26  150  65.8    184     185
# Total:         42  166  65.9    201     201
#
# Percentage of the requests served within a certain time (ms)
#   50%    201
#   66%    201
#   75%    201
#   80%    201
#   90%    201
#   95%    201
#   98%    201
#   99%    201
#  100%    201 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.166 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    60.08 [#/sec] (mean)
# Time per request:       166.451 [ms] (mean)
# Time per request:       16.645 [ms] (mean, across all concurrent requests)
# Transfer rate:          12.73 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   10   1.9     10      13
# Processing:    20   60  34.2     89      92
# Waiting:       18   58  34.2     87      90
# Total:         29   70  35.3    101     102
#
# Percentage of the requests served within a certain time (ms)
#   50%    101
#   66%    102
#   75%    102
#   80%    102
#   90%    102
#   95%    102
#   98%    102
#   99%    102
#  100%    102 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.071 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    140.91 [#/sec] (mean)
# Time per request:       70.965 [ms] (mean)
# Time per request:       7.097 [ms] (mean, across all concurrent requests)
# Transfer rate:          29.86 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        8   10   1.5     10      12
# Processing:    15   35   7.4     38      41
# Waiting:       14   33   6.9     34      39
# Total:         23   45   7.7     47      49
#
# Percentage of the requests served within a certain time (ms)
#   50%     47
#   66%     48
#   75%     48
#   80%     48
#   90%     49
#   95%     49
#   98%     49
#   99%     49
#  100%     49 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.063 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    157.54 [#/sec] (mean)
# Time per request:       63.476 [ms] (mean)
# Time per request:       6.348 [ms] (mean, across all concurrent requests)
# Transfer rate:          33.38 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   10   2.6     11      14
# Processing:    15   28   5.0     28      32
# Waiting:       14   26   4.8     26      31
# Total:         23   38   5.4     39      41
#
# Percentage of the requests served within a certain time (ms)
#   50%     39
#   66%     40
#   75%     40
#   80%     41
#   90%     41
#   95%     41
#   98%     41
#   99%     41
#  100%     41 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.249 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    40.21 [#/sec] (mean)
# Time per request:       248.695 [ms] (mean)
# Time per request:       24.869 [ms] (mean, across all concurrent requests)
# Transfer rate:          8.52 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   10   2.4     10      13
# Processing:    16   78  81.3     24     217
# Waiting:       14   76  81.4     20     215
# Total:         23   88  83.0     33     226
#
# Percentage of the requests served within a certain time (ms)
#   50%     33
#   66%    125
#   75%    127
#   80%    226
#   90%    226
#   95%    226
#   98%    226
#   99%    226
#  100%    226 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.258 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    38.69 [#/sec] (mean)
# Time per request:       258.494 [ms] (mean)
# Time per request:       25.849 [ms] (mean, across all concurrent requests)
# Transfer rate:          8.20 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   10   3.3      9      18
# Processing:    19   88  42.5     91     189
# Waiting:       18   87  42.5     89     188
# Total:         27   99  42.8    100     198
#
# Percentage of the requests served within a certain time (ms)
#   50%    100
#   66%    100
#   75%    100
#   80%    101
#   90%    198
#   95%    198
#   98%    198
#   99%    198
#  100%    198 (longest request)
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160545.69136863155&y=502116.0063503415
# Document Length:        76 bytes
#
# Concurrency Level:      10
# Time taken for tests:   0.175 seconds
# Complete requests:      10
# Failed requests:        0
# Non-2xx responses:      10
# Total transferred:      2170 bytes
# HTML transferred:       760 bytes
# Requests per second:    57.11 [#/sec] (mean)
# Time per request:       175.094 [ms] (mean)
# Time per request:       17.509 [ms] (mean, across all concurrent requests)
# Transfer rate:          12.10 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7   10   2.3     10      14
# Processing:    22   75  29.1     92      94
# Waiting:       19   72  28.9     89      91
# Total:         30   85  30.0    102     103
#
# Percentage of the requests served within a certain time (ms)
#   50%    102
#   66%    102
#   75%    102
#   80%    103
#   90%    103
#   95%    103
#   98%    103
#   99%    103
#  100%    103 (longest request)
