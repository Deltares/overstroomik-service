# %%
server_url = 'https://geodata.basisinformatie-overstromingen.nl'
path = '/geoserver/wms?service=WMS&request=GetMap&layers=MEGO%3AMEGO_overstromingNL_WaterdiepteKlasse_Group&styles=&format=image%2Fpng&transparent=true&version=1.1.1&baselayer=false&tiled=true&height=256&width=256&srs=EPSG%3A28992&bbox=155000.00011739583,463000.00044581917,168762.56012993932,476762.560'
url = f'{server_url}{path}'
# !ab -n 20 -c 5 "$url"
# Out:
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking geodata.basisinformatie-overstromingen.nl (be patient).....done
#
#
# Server Software:        Apache-Coyote/1.1
# Server Hostname:        geodata.basisinformatie-overstromingen.nl
# Server Port:            443
# SSL/TLS Protocol:       TLSv1.2,ECDHE-RSA-AES128-GCM-SHA256,2048,128
# Server Temp Key:        ECDH P-256 256 bits
# TLS Server Name:        geodata.basisinformatie-overstromingen.nl
#
# Document Path:          /geoserver/wms?service=WMS&request=GetMap&layers=MEGO%3AMEGO_overstromingNL_WaterdiepteKlasse_Group&styles=&format=image%2Fpng&transparent=true&version=1.1.1&baselayer=false&tiled=true&height=256&width=256&srs=EPSG%3A28992&bbox=155000.00011739583,463000.00044581917,168762.56012993932,476762.560
# Document Length:        14104 bytes
#
# Concurrency Level:      5
# Time taken for tests:   7.535 seconds
# Complete requests:      20
# Failed requests:        0
# Total transferred:      287740 bytes
# HTML transferred:       282080 bytes
# Requests per second:    2.65 [#/sec] (mean)
# Time per request:       1883.850 [ms] (mean)
# Time per request:       376.770 [ms] (mean, across all concurrent requests)
# Transfer rate:          37.29 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:      106  118  10.4    119     144
# Processing:  1197 1413 141.5   1415    1673
# Waiting:     1191 1408 141.5   1415    1668
# Total:       1326 1530 144.5   1535    1818
#
# Percentage of the requests served within a certain time (ms)
#   50%   1535
#   66%   1622
#   75%   1654
#   80%   1666
#   90%   1747
#   95%   1818
#   98%   1818
#   99%   1818
#  100%   1818 (longest request)

# %%
server_url = 'https://geodata.basisinformatie-overstromingen.nl'
path = '/overstroom-ik.html?adres=2631TG&latitude=&longiqtude='
url = f'{server_url}{path}'
# !ab -n 20 -c 5 "$url"
# Out:
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking geodata.basisinformatie-overstromingen.nl (be patient).....done
#
#
# Server Software:        Apache-Coyote/1.1
# Server Hostname:        geodata.basisinformatie-overstromingen.nl
# Server Port:            443
# SSL/TLS Protocol:       TLSv1.2,ECDHE-RSA-AES128-GCM-SHA256,2048,128
# Server Temp Key:        ECDH P-256 256 bits
# TLS Server Name:        geodata.basisinformatie-overstromingen.nl
#
# Document Path:          /overstroom-ik.html?adres=2631TG&latitude=&longiqtude=
# Document Length:        127 bytes
#
# Concurrency Level:      5
# Time taken for tests:   0.816 seconds
# Complete requests:      20
# Failed requests:        0
# Non-2xx responses:      20
# Total transferred:      7740 bytes
# HTML transferred:       2540 bytes
# Requests per second:    24.52 [#/sec] (mean)
# Time per request:       203.951 [ms] (mean)
# Time per request:       40.790 [ms] (mean, across all concurrent requests)
# Transfer rate:          9.27 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:      110  127   9.6    126     149
# Processing:    34   37   2.0     37      41
# Waiting:       33   35   1.8     35      38
# Total:        145  163  10.9    162     187
#
# Percentage of the requests served within a certain time (ms)
#   50%    162
#   66%    169
#   75%    171
#   80%    175
#   90%    180
#   95%    187
#   98%    187
#   99%    187
#  100%    187 (longest request)

# %%
server_url = 'http://34.120.151.162'
path = '/'
url = f'{server_url}{path}'
# !ab -n 20 -c 5 "$url"
# Out:
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:        uvicorn
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /
# Document Length:        37 bytes
#
# Concurrency Level:      5
# Time taken for tests:   0.132 seconds
# Complete requests:      20
# Failed requests:        0
# Total transferred:      3580 bytes
# HTML transferred:       740 bytes
# Requests per second:    151.66 [#/sec] (mean)
# Time per request:       32.967 [ms] (mean)
# Time per request:       6.593 [ms] (mean, across all concurrent requests)
# Transfer rate:          26.51 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        6    8   0.9      8       9
# Processing:    15   18   2.2     18      23
# Waiting:       15   18   2.0     17      22
# Total:         22   26   2.7     26      31
#
# Percentage of the requests served within a certain time (ms)
#   50%     26
#   66%     27
#   75%     29
#   80%     29
#   90%     30
#   95%     31
#   98%     31
#   99%     31
#  100%     31 (longest request)

# %%
server_url = 'http://34.120.151.162'
path = '/by_rd?x=160544.902&y=502115.495'
url = f'{server_url}{path}'
# !ab -n 20 -c 5 "$url"
# Out:
# This is ApacheBench, Version 2.3 <$Revision: 1843412 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking 34.120.151.162 (be patient).....done
#
#
# Server Software:        uvicorn
# Server Hostname:        34.120.151.162
# Server Port:            80
#
# Document Path:          /by_rd?x=160544.902&y=502115.495
# Document Length:        391 bytes
#
# Concurrency Level:      5
# Time taken for tests:   7.303 seconds
# Complete requests:      20
# Failed requests:        0
# Total transferred:      10680 bytes
# HTML transferred:       7820 bytes
# Requests per second:    2.74 [#/sec] (mean)
# Time per request:       1825.630 [ms] (mean)
# Time per request:       365.126 [ms] (mean, across all concurrent requests)
# Transfer rate:          1.43 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        7    9   1.8      8      14
# Processing:   500 1654 413.4   1656    2274
# Waiting:      500 1653 413.3   1656    2274
# Total:        509 1663 413.4   1664    2283
#
# Percentage of the requests served within a certain time (ms)
#   50%   1664
#   66%   1911
#   75%   1946
#   80%   2081
#   90%   2143
#   95%   2283
#   98%   2283
#   99%   2283
#  100%   2283 (longest request)
